# %%
import pandas as pd

# %%
bikes = pd.read_csv("Data/Bikes_Clean.csv")
weather = pd.read_csv("Data/Weather_Clean.csv")
holidays = pd.read_csv("Data/Holidays_Clean.csv")

# %%
data = bikes.merge(holidays, how="left", left_on="Date", right_on="Date")
data = data.merge(weather, how="left", left_on="Date", right_on="Date")

# %%
data["Holiday"].where(pd.isnull(data["Holiday"]), 0, inplace=True)
data["Holiday"].where(not pd..isnull(data["Holiday"])  , 1, inplace=True)
data.head()
# Out:
#          Date   Trips         Holiday  PRCP  SNOW  TMAX  TMIN  TAVG  AWND
# 0  2015-01-01  2611.0  New Year's Day   0.0   0.0   8.3  -2.7   1.7   3.7
# 1  2015-01-02  5155.0             NaN   0.0   0.0   9.4   1.7   5.3   1.3
# 2  2015-01-03  1718.0             NaN  12.7   0.0   5.6   1.1   4.0   1.5
# 3  2015-01-04  3711.0             NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  2015-01-05  5262.0             NaN   0.0   0.0  11.1  -1.6   7.8   6.4

# %%
data = data.dropna(axis=0, how="any")

# %%
data.describe()
# Out:
#               Trips      PRCP       SNOW       TMAX       TMIN       TAVG  \
# count     24.000000  24.00000  24.000000  24.000000  24.000000  24.000000
# mean    7045.791667   2.42500   6.041667  17.450000   8.000000  12.441667
# std     4461.864896   5.28988  20.473693  10.543203   9.881207   9.992385
# min      501.000000   0.00000   0.000000  -6.600000 -12.100000  -9.800000
# 25%     2583.000000   0.00000   0.000000   9.850000   2.075000   6.425000
# 50%     8724.000000   0.00000   0.000000  19.150000   7.500000  13.650000
# 75%    10674.000000   0.85000   0.000000  24.600000  18.450000  21.650000
# max    13505.000000  21.60000  74.000000  32.200000  22.200000  25.900000
#
#             AWND
# count  24.000000
# mean    3.075000
# std     1.603054
# min     1.000000
# 25%     2.075000
# 50%     2.700000
# 75%     3.700000
# max     7.900000

# %%
data.head()
# Out:
#            Date    Trips                      Holiday  PRCP  SNOW  TMAX  TMIN  \
# 0    2015-01-01   2611.0               New Year's Day   0.0   0.0   8.3  -2.7
# 18   2015-01-19   4687.0  Martin Luther King, Jr. Day   0.0   0.0  10.0   0.6
# 46   2015-02-16   1335.0        Washington's Birthday   7.4  74.0  -6.6 -12.1
# 105  2015-04-16  11687.0             Emancipation Day   1.0   0.0  23.3  11.1
# 143  2015-05-25  11990.0                 Memorial Day   0.0   0.0  29.4  19.4
#
#      TAVG  AWND
# 0     1.7   3.7
# 18    6.6   2.8
# 46   -9.8   3.4
# 105  16.9   2.8
# 143  24.4   5.2

# %%
import matplotlib
# %matplotlib inline
data.hist(bins=50, figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10bb7bfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e424c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10edcf0b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10edf8128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ee32048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ee32080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10eeb5dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ee4edd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ef09dd8>]], dtype=object)

# %%
data["isHoliday"] = data["Holiday"].map[]
# Out:
#   File "<ipython-input-109-bfbffc96e27d>", line 1
#     data["isHoliday"] = data["Holiday"].map[]
#                                             ^
# SyntaxError: invalid syntax
